# %%
# !pip install tqdm

# %%
# Долго работает, до конца не запускалось
from base import BasicUTRP, create_sample_problem

W, D = create_sample_problem(n=10)

utrp_solver = BasicUTRP(
    weight_matrix=W,
    demand_matrix=D,
    min_vertices=3,
    max_vertices=8,
    num_routes=4
)

print("Запуск базового алгоритма UTRP...")
best_solution, best_att, best_trt = utrp_solver.basic_search(num_iterations=10)

print(f"\nЛучшее решение:")
print(f"ATT: {best_att:.2f} мин")
print(f"TRT: {best_trt:.2f} мин")
print(f"Маршруты: {best_solution}")
# Out:
# Запуск базового алгоритма UTRP...
# Генерация начальных решений...
#   0%|                                                                                                                               | 0/5 [00:00<?, ?it/s]
#   0%|                                                                                                                               | 0/9 [00:14<?, ?it/s]
#   0%|                                                                                                                               | 0/5 [00:14<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 15
#       6 utrp_solver = BasicUTRP(
#       7     weight_matrix=W,
#       8     demand_matrix=D,
#    (...)
#      11     num_routes=4
#      12 )
#      14 print("Запуск базового алгоритма UTRP...")
# ---> 15 best_solution, best_att, best_trt = utrp_solver.basic_search(num_iterations=10)
#      17 print(f"\nЛучшее решение:")
#      18 print(f"ATT: {best_att:.2f} мин")
#
# File /pbabkin/main/mipt/modeling_utrp/base.py:356, in BasicUTRP.basic_search(self, num_iterations)
#     352 """
#     353 Базовый поисковый алгоритм
#     354 """
#     355 print("Генерация начальных решений...")
# --> 356 initial_solutions = self.generate_initial_solutions(num_solutions=5)
#     357 if not initial_solutions:
#     358     raise ValueError("Не удалось сгенерировать начальные решения")
#
# File /pbabkin/main/mipt/modeling_utrp/base.py:116, in BasicUTRP.generate_initial_solutions(self, k, num_solutions)
#     114 for i in range(self.n):
#     115     for j in tqdm(range(i+1, self.n)):
# --> 116         paths = self.yen_ksp(i, j, k)
#     117         all_ksp.extend(paths)
#     118 print(f"Сгенерировано {len(all_ksp)} кандидатов маршрутов")
#
# File /pbabkin/main/mipt/modeling_utrp/base.py:62, in BasicUTRP.yen_ksp(self, source, target, k)
#      59 if dist[target] == float('inf'):
#      60     return paths
# ---> 62 path = self._reconstruct_path(source, target, dist)
#      63 if path:
#      64     paths.append(path)
#
# File /pbabkin/main/mipt/modeling_utrp/base.py:92, in BasicUTRP._reconstruct_path(self, source, target, dist)
#      90 found = False
#      91 for prev in range(self.n):
# ---> 92     if (self.W[prev][current] < float('inf') and
#      93         abs(dist[current] - dist[prev] - self.W[prev][current]) < 1e-6):
#      94         path.append(prev)
#      95         current = prev
#
# KeyboardInterrupt:

# %%
from enhanced import EnhancedUTRP, create_sample_problem

W, D = create_sample_problem(n=10)

utrp_solver = EnhancedUTRP(
    weight_matrix=W,
    demand_matrix=D,
    min_vertices=3,
    max_vertices=8,
    num_routes=5
)

print("Запуск DBMOSA...")
dbmosa_solution, dbmosa_att, dbmosa_trt = utrp_solver.dbmosa(max_iterations=500)
print(f"DBMOSA Результат: ATT={dbmosa_att:.2f}, TRT={dbmosa_trt:.2f}")

print("\nЗапуск NSGA-II...")
nsga_front = utrp_solver.nsga_ii(population_size=30, generations=50)
if nsga_front:
    best_nsga = min(nsga_front, key=lambda x: (x[1], x[2]))
    print(f"NSGA-II Лучшее: ATT={best_nsga[1]:.2f}, TRT={best_nsga[2]:.2f}")
    print(f"Размер Pareto front: {len(nsga_front)}")

print("\nСтатистика операторов:")
for llh_name in utrp_solver.operators.keys():
    apps = utrp_solver.llh_applications[llh_name]
    success = utrp_solver.llh_successes[llh_name]
    success_rate = success / apps if apps > 0 else 0
    print(f"Оператор {llh_name}: Применений={apps}, Успехов={success}, "
            f"Успешность={success_rate:.2f}")
# Out:
# Запуск DBMOSA...
# DBMOSA Iteration 0: Temp=0.9500, Archive size=2, Best ATT=21.01
# DBMOSA Iteration 100: Temp=0.0056, Archive size=32, Best ATT=16.06
# DBMOSA Iteration 200: Temp=0.0000, Archive size=20, Best ATT=16.06
# DBMOSA Iteration 300: Temp=0.0000, Archive size=47, Best ATT=16.06
# DBMOSA Iteration 400: Temp=0.0000, Archive size=34, Best ATT=16.06
# DBMOSA Результат: ATT=4.60, TRT=inf
#
# Запуск NSGA-II...
# NSGA-II Generation 0: Best ATT=17.47, Best TRT=67.11, Front size=1
# NSGA-II Generation 10: Best ATT=13.28, Best TRT=46.02, Front size=8
# NSGA-II Generation 20: Best ATT=7.92, Best TRT=53.51, Front size=10
# NSGA-II Generation 30: Best ATT=10.05, Best TRT=46.02, Front size=11
# NSGA-II Generation 40: Best ATT=8.85, Best TRT=60.94, Front size=12
# NSGA-II Лучшее: ATT=11.42, TRT=99.55
# Размер Pareto front: 9
#
# Статистика операторов:
# Оператор a: Применений=39, Успехов=24, Успешность=0.62
# Оператор b: Применений=54, Успехов=27, Успешность=0.50
# Оператор c: Применений=95, Успехов=61, Успешность=0.64
# Оператор d: Применений=15, Успехов=3, Успешность=0.20
# Оператор e: Применений=19, Успехов=5, Успешность=0.26
# Оператор f: Применений=44, Успехов=31, Успешность=0.70
# Оператор g: Применений=46, Успехов=22, Успешность=0.48
# Оператор h: Применений=58, Успехов=45, Успешность=0.78
# Оператор i: Применений=57, Успехов=35, Успешность=0.61
# Оператор j: Применений=73, Успехов=43, Успешность=0.59

# %%
from repaired import EnhancedUTRP, create_sample_problem

W, D = create_sample_problem(n=10)

utrp_solver = EnhancedUTRP(
    weight_matrix=W,
    demand_matrix=D,
    min_vertices=3,
    max_vertices=8,
    num_routes=5
)

print("Запуск DBMOSA...")
dbmosa_solution, dbmosa_att, dbmosa_trt = utrp_solver.dbmosa(max_iterations=500)
print(f"DBMOSA Результат: ATT={dbmosa_att:.2f}, TRT={dbmosa_trt:.2f}")

print("\nЗапуск NSGA-II...")
nsga_front = utrp_solver.nsga_ii(population_size=30, generations=50)
if nsga_front:
    best_nsga = min(nsga_front, key=lambda x: (x[1], x[2]))
    print(f"NSGA-II Лучшее: ATT={best_nsga[1]:.2f}, TRT={best_nsga[2]:.2f}")
    print(f"Размер Pareto front: {len(nsga_front)}")

print("\nСтатистика операторов:")
for llh_name in utrp_solver.operators.keys():
    apps = utrp_solver.llh_applications[llh_name]
    success = utrp_solver.llh_successes[llh_name]
    success_rate = success / apps if apps > 0 else 0
    print(f"Оператор {llh_name}: Применений={apps}, Успехов={success}, "
            f"Успешность={success_rate:.2f}")
# Out:
# Запуск DBMOSA...
# DBMOSA Iteration 0: Temp=0.9500, Archive size=1, Best ATT=22.43
# DBMOSA Iteration 100: Temp=0.0099, Archive size=47, Best ATT=22.43
# DBMOSA Iteration 200: Temp=0.0001, Archive size=67, Best ATT=22.23
# DBMOSA Результат: ATT=20.16, TRT=114.44
#
# Запуск NSGA-II...
# NSGA-II Generation 0: Best ATT=22.46, Best TRT=85.17, Front size=1
# NSGA-II Generation 10: Best ATT=21.06, Best TRT=77.75, Front size=16
# NSGA-II Generation 20: Best ATT=20.92, Best TRT=77.75, Front size=17
# NSGA-II Generation 30: Best ATT=20.26, Best TRT=85.17, Front size=14
# NSGA-II Generation 40: Best ATT=20.83, Best TRT=85.17, Front size=18
# NSGA-II Лучшее: ATT=19.77, TRT=157.66
# Размер Pareto front: 18
#
# Статистика операторов:
# Оператор a: Применений=38, Успехов=31, Успешность=0.82
# Оператор b: Применений=43, Успехов=31, Успешность=0.72
# Оператор c: Применений=79, Успехов=66, Успешность=0.84
# Оператор d: Применений=114, Успехов=106, Успешность=0.93
# Оператор e: Применений=15, Успехов=5, Успешность=0.33
# Оператор f: Применений=46, Успехов=32, Успешность=0.70
# Оператор g: Применений=11, Успехов=3, Успешность=0.27
# Оператор h: Применений=46, Успехов=37, Успешность=0.80
# Оператор i: Применений=16, Успехов=11, Успешность=0.69
# Оператор j: Применений=92, Успехов=78, Успешность=0.85
